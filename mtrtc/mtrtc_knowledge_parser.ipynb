# %%
from pymongo import MongoClient
import json

with open(os.path.expanduser('~/.mongo/mongo.json'),'r') as config:
    mongo_uri = json.load(config)['mongo_uri']
client = MongoClient(mongo_uri)
db = client.forethought

organization_id = '451'
moc = db[str(organization_id)]

# %%
def populate(data):
	for i in mongo_org_collection.find({"doc_type":"mind_touch_page", "is_deleted": False}):
		id = i['id']
		url = i['link']
		# print(f"Processing: {url}")
		for k, v in data.items():
			exclude = v['default']
			for x in v['exclude']:
				if x in url:
					exclude = True
            for x in endpoints:
				if url.endswith(x):
					exclude = True
			for x in v.get('force_include', []):
				if x == url or x in url:
					exclude = False
			if exclude:
				data[k]["do_not_include"].add(id)
				# print(f"Url: {url} not included for {k}")
	return data
# pages = [(i['id'], i['link']) for i in )]
endpoints = ["/TeamConnect", "/Collaborati", "/Suite", "/Acuity", "/Corridor", "/LegalHold", "/Lawtrac", "/TeamConnectEssentials", "/Viewabill", "/GettingContractsDone", "/VendorInsight", "/PolicyHub", "/CMOCompliance", "/DataStore_DSX", "/ClusterSeven", "/Procipient", "/OpRiskControl", "/INSZoom", "/Tracker_IMS", "/TAP"]

#moc = mongo.get_db(collection=402)
data = {
	"team_connect": {
		'default': False,
		"do_not_include": set(),
		"exclude": ["/Collaborati", "/Suite", "/Acuity", "/Corridor", "/LegalHold", "/Lawtrac", "/TeamConnectEssentials", "/Viewabill", "/GettingContractsDone", "/VendorInsight", "/PolicyHub", "/CMOCompliance", "/DataStore_DSX", "/ClusterSeven", "/Procipient", "/OpRiskControl", "/INSZoom", "/Tracker_IMS", "/TAP"]
	},
    "collaborati": {
		'default': False,
		"do_not_include": set(),
		"exclude": ["/TeamConnect", "/Suite", "/Acuity", "/Corridor", "/LegalHold", "/Lawtrac", "/TeamConnectEssentials", "/Viewabill", "/GettingContractsDone", "/VendorInsight", "/PolicyHub", "/CMOCompliance", "/DataStore_DSX", "/ClusterSeven", "/Procipient", "/OpRiskControl", "/INSZoom", "/Tracker_IMS", "/TAP"]
	},
    "suite": {
		'default': False,
		"do_not_include": set(),
		"exclude": ["/TeamConnect", "/Collaborati", "/Acuity", "/Corridor", "/LegalHold", "/Lawtrac", "/TeamConnectEssentials", "/Viewabill", "/GettingContractsDone", "/VendorInsight", "/PolicyHub", "/CMOCompliance", "/DataStore_DSX", "/ClusterSeven", "/Procipient", "/OpRiskControl", "/INSZoom", "/Tracker_IMS", "/TAP"]
	},
    "acuity_elm": {
		'default': False,
		"do_not_include": set(),
		"exclude": ["/TeamConnect", "/Collaborati", "/Suite", "/Corridor", "/LegalHold", "/Lawtrac", "/TeamConnectEssentials", "/Viewabill", "/GettingContractsDone", "/VendorInsight", "/PolicyHub", "/CMOCompliance", "/DataStore_DSX", "/ClusterSeven", "/Procipient", "/OpRiskControl", "/INSZoom", "/Tracker_IMS", "/TAP"]
	},
    "corridor": {
		'default': False,
		"do_not_include": set(),
		"exclude": ["/TeamConnect", "/Collaborati", "/Suite", "/Acuity", "/LegalHold", "/Lawtrac", "/TeamConnectEssentials", "/Viewabill", "/GettingContractsDone", "/VendorInsight", "/PolicyHub", "/CMOCompliance", "/DataStore_DSX", "/ClusterSeven", "/Procipient", "/OpRiskControl", "/INSZoom", "/Tracker_IMS", "/TAP"]
	},
    "legal_hold": {
		'default': False,
		"do_not_include": set(),
		"exclude": ["/TeamConnect", "/Collaborati", "/Suite", "/Acuity", "/Corridor", "/Lawtrac", "/TeamConnectEssentials", "/Viewabill", "/GettingContractsDone", "/VendorInsight", "/PolicyHub", "/CMOCompliance", "/DataStore_DSX", "/ClusterSeven", "/Procipient", "/OpRiskControl", "/INSZoom", "/Tracker_IMS", "/TAP"]
	},
    "lawtrac": {
		'default': False,
		"do_not_include": set(),
		"exclude": ["/TeamConnect", "/Collaborati", "/Suite", "/Acuity", "/Corridor", "/LegalHold", "/TeamConnectEssentials", "/Viewabill", "/GettingContractsDone", "/VendorInsight", "/PolicyHub", "/CMOCompliance", "/DataStore_DSX", "/ClusterSeven", "/Procipient", "/OpRiskControl", "/INSZoom", "/Tracker_IMS", "/TAP"]
	},
    "team_connect_essentials": {
		'default': False,
		"do_not_include": set(),
		"exclude": ["/TeamConnect", "/Collaborati", "/Suite", "/Acuity", "/Corridor", "/LegalHold", "/Lawtrac", "/Viewabill", "/GettingContractsDone", "/VendorInsight", "/PolicyHub", "/CMOCompliance", "/DataStore_DSX", "/ClusterSeven", "/Procipient", "/OpRiskControl", "/INSZoom", "/Tracker_IMS", "/TAP"]
	},
    "viewa_bill": {
		'default': False,
		"do_not_include": set(),
		"exclude": ["/TeamConnect", "/Collaborati", "/Suite", "/Acuity", "/Corridor", "/LegalHold", "/Lawtrac", "/TeamConnectEssentials", "/GettingContractsDone", "/VendorInsight", "/PolicyHub", "/CMOCompliance", "/DataStore_DSX", "/ClusterSeven", "/Procipient", "/OpRiskControl", "/INSZoom", "/Tracker_IMS", "/TAP"]
	},
    "getting_contracts_done": {
		'default': False,
		"do_not_include": set(),
		"exclude": ["/TeamConnect", "/Collaborati", "/Suite", "/Acuity", "/Corridor", "/LegalHold", "/Lawtrac", "/TeamConnectEssentials", "/Viewabill", "/VendorInsight", "/PolicyHub", "/CMOCompliance", "/DataStore_DSX", "/ClusterSeven", "/Procipient", "/OpRiskControl", "/INSZoom", "/Tracker_IMS", "/TAP"]
	},
    "vendor_insight": {
		'default': False,
		"do_not_include": set(),
		"exclude": ["/TeamConnect", "/Collaborati", "/Suite", "/Acuity", "/Corridor", "/LegalHold", "/Lawtrac", "/TeamConnectEssentials", "/Viewabill", "/GettingContractsDone", "/PolicyHub", "/CMOCompliance", "/DataStore_DSX", "/ClusterSeven", "/Procipient", "/OpRiskControl", "/INSZoom", "/Tracker_IMS", "/TAP"]
	},
    "policy_hub": {
		'default': False,
		"do_not_include": set(),
		"exclude": ["/TeamConnect", "/Collaborati", "/Suite", "/Acuity", "/Corridor", "/LegalHold", "/Lawtrac", "/TeamConnectEssentials", "/Viewabill", "/GettingContractsDone", "/VendorInsight", "/CMOCompliance", "/DataStore_DSX", "/ClusterSeven", "/Procipient", "/OpRiskControl", "/INSZoom", "/Tracker_IMS", "/TAP"]
	},
    "cmo_compliance": {
		'default': False,
		"do_not_include": set(),
		"exclude": ["/TeamConnect", "/Collaborati", "/Suite", "/Acuity", "/Corridor", "/LegalHold", "/Lawtrac", "/TeamConnectEssentials", "/Viewabill", "/GettingContractsDone", "/VendorInsight", "/PolicyHub", "/DataStore_DSX", "/ClusterSeven", "/Procipient", "/OpRiskControl", "/INSZoom", "/Tracker_IMS", "/TAP"]
	},
    "data_store": {
		'default': False,
		"do_not_include": set(),
		"exclude": ["/TeamConnect", "/Collaborati", "/Suite", "/Acuity", "/Corridor", "/LegalHold", "/Lawtrac", "/TeamConnectEssentials", "/Viewabill", "/GettingContractsDone", "/VendorInsight", "/PolicyHub", "/CMOCompliance", "/ClusterSeven", "/Procipient", "/OpRiskControl", "/INSZoom", "/Tracker_IMS", "/TAP"]
	},
    "cluster_seven": {
		'default': False,
		"do_not_include": set(),
		"exclude": ["/TeamConnect", "/Collaborati", "/Suite", "/Acuity", "/Corridor", "/LegalHold", "/Lawtrac", "/TeamConnectEssentials", "/Viewabill", "/GettingContractsDone", "/VendorInsight", "/PolicyHub", "/CMOCompliance", "/DataStore_DSX", "/Procipient", "/OpRiskControl", "/INSZoom", "/Tracker_IMS", "/TAP"]
	},
    "procipient": {
		'default': False,
		"do_not_include": set(),
		"exclude": ["/TeamConnect", "/Collaborati", "/Suite", "/Acuity", "/Corridor", "/LegalHold", "/Lawtrac", "/TeamConnectEssentials", "/Viewabill", "/GettingContractsDone", "/VendorInsight", "/PolicyHub", "/CMOCompliance", "/DataStore_DSX", "/ClusterSeven", "/OpRiskControl", "/INSZoom", "/Tracker_IMS", "/TAP"]
	},
    "op_risk_control": {
		'default': False,
		"do_not_include": set(),
		"exclude": ["/TeamConnect", "/Collaborati", "/Suite", "/Acuity", "/Corridor", "/LegalHold", "/Lawtrac", "/TeamConnectEssentials", "/Viewabill", "/GettingContractsDone", "/VendorInsight", "/PolicyHub", "/CMOCompliance", "/DataStore_DSX", "/ClusterSeven", "/Procipient", "/INSZoom", "/Tracker_IMS", "/TAP"]
	},
    "ins_zoom": {
		'default': False,
		"do_not_include": set(),
		"exclude": ["/TeamConnect", "/Collaborati", "/Suite", "/Acuity", "/Corridor", "/LegalHold", "/Lawtrac", "/TeamConnectEssentials", "/Viewabill", "/GettingContractsDone", "/VendorInsight", "/PolicyHub", "/CMOCompliance", "/DataStore_DSX", "/ClusterSeven", "/Procipient", "/OpRiskControl", "/Tracker_IMS", "/TAP"]
	},
    "tracker_ims": {
		'default': False,
		"do_not_include": set(),
		"exclude": ["/TeamConnect", "/Collaborati", "/Suite", "/Acuity", "/Corridor", "/LegalHold", "/Lawtrac", "/TeamConnectEssentials", "/Viewabill", "/GettingContractsDone", "/VendorInsight", "/PolicyHub", "/CMOCompliance", "/DataStore_DSX", "/ClusterSeven", "/Procipient", "/OpRiskControl", "/INSZoom", "/TAP"]
	},
    "tap_workflow_automation": {
		'default': False,
		"do_not_include": set(),
		"exclude": ["/TeamConnect", "/Collaborati", "/Suite", "/Acuity", "/Corridor", "/LegalHold", "/Lawtrac", "/TeamConnectEssentials", "/Viewabill", "/GettingContractsDone", "/VendorInsight", "/PolicyHub", "/CMOCompliance", "/DataStore_DSX", "/ClusterSeven", "/Procipient", "/OpRiskControl", "/INSZoom", "/Tracker_IMS"]
	}
}

# %%
# #data = populate(data)
# print(json.dumps(list(v["do_not_include"])))
ttl = 4872
for k,v in data.items():
    print(k, len(v["do_not_include"]))
    l = len(list(v["do_not_include"]))
    print(f"Total Ignored: {l}")
    print(f"Total Not Ignored: {ttl - l}")
    print()
    print()
# out = {k:list(v['do_not_include']) for k,v in data.items()}
# with open('mtrtc_urls.json', 'w') as f:
#     json.dump(out, f, indent=2)
# Out:
# team_connect 3671
# Total Ignored: 3671
# Total Not Ignored: 1201
#
#
# collaborati 4390
# Total Ignored: 4390
# Total Not Ignored: 482
#
#
# suite 3871
# Total Ignored: 3871
# Total Not Ignored: 1001
#
#
# acuity_elm 4647
# Total Ignored: 4647
# Total Not Ignored: 225
#
#
# corridor 4604
# Total Ignored: 4604
# Total Not Ignored: 268
#
#
# legal_hold 4570
# Total Ignored: 4570
# Total Not Ignored: 302
#
#
# lawtrac 3820
# Total Ignored: 3820
# Total Not Ignored: 1052
#
#
# team_connect_essentials 4650
# Total Ignored: 4650
# Total Not Ignored: 222
#
#
# viewa_bill 4553
# Total Ignored: 4553
# Total Not Ignored: 319
#
#
# getting_contracts_done 4607
# Total Ignored: 4607
# Total Not Ignored: 265
#
#
# vendor_insight 4650
# Total Ignored: 4650
# Total Not Ignored: 222
#
#
# policy_hub 4641
# Total Ignored: 4641
# Total Not Ignored: 231
#
#
# cmo_compliance 4623
# Total Ignored: 4623
# Total Not Ignored: 249
#
#
# data_store 4031
# Total Ignored: 4031
# Total Not Ignored: 841
#
#
# ...
